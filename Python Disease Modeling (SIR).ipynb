# %%
# Python Disease X Model Simulation
# Susceptible Infectious Recovered (SIR)
# Source = https://hackernoon.com/simulating-infectious-disease-spread-with-python-sir-and-seir-models
# Source Author = Olaoluwa Afolabi

# %%
import numpy as np
import pandas as pd
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# %%
# SIR Model Equations
def SIR_Model(y, t, beta, gamma):
    S,I,R=y
    dSdt = -beta * S * I
    dIdt = beta * S * I - gamma * I
    dRdt = gamma * I
    return [dSdt, dIdt, dRdt]

# %%
# Initial Conditions
S0=0.99  # 99% of the population is Susceptible to Disease X at simulation start/time 0
I0= 0.01 # 1% of individuals are infected at time 0 
R0=0.00  # 0% or no individuals have recovered from Disease X at time 0
y0 = [S0,I0,R0]

# %%
# Model Parameters
# Beta is the transmission rate set to 30% and gamma = 10% in accordance with the Source Author's initial selection
beta = 0.3
gamma = 0.1

# %%
#Time Vector
t = np.linspace(0 , 200, 200) #Simulate for 200 days

# %%
#Solve the SIR model equations using odeint()
solution = odeint(SIR_Model, y0,t,args=(beta,gamma))

# %%
#Extract Results
S,I,R = solution.T

# %%
# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(t, S, label='Susceptible')
plt.plot(t, I, label='Infected')
plt.plot(t, R, label='Recovered')
plt.xlabel('Time (days)')
plt.ylabel('Proportion of Population')
plt.title('SIR Model Simulation')
plt.legend()
plt.grid(True)
plt.show()

# %%
# I am going to the run the model again with double the transmission rate (beta=60%) and double the initial infected rate (gamma=2%)
# Model Parameters
# Beta is the transmission rate set to 30% and gamma = 20% in accordance with the Source Author's initial selection
beta = 0.6
gamma = 0.2

# %%
#Solve the SIR model equations using odeint()
solution = odeint(SIR_Model, y0,t,args=(beta,gamma))

# %%
#Extract Results
S,I,R = solution.T

# %%
# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(t, S, label='Susceptible')
plt.plot(t, I, label='Infected')
plt.plot(t, R, label='Recovered')
plt.xlabel('Time (days)')
plt.ylabel('Proportion of Population')
plt.title('SIR Model Simulation')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Note: The initial time of approximate infection peak was 25 days but reduced to T*?
# I will replot with smaller x-axis ticks to more clearly identify the peak infection rate
# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(t, S, label='Susceptible')
plt.plot(t, I, label='Infected')
plt.plot(t, R, label='Recovered')
plt.xlabel('Time (days)')
plt.ylabel('Proportion of Population')
plt.title('SIR Model Simulation')
plt.xticks(np.arange(0, 200, 13))
plt.legend()
plt.grid(True)
plt.show()

# %%
# Note: The initial time of approximate infection peak was 25 days but reduced to T* = approx. 13 days
